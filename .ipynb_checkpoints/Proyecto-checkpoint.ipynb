# %% [markdown]
# Se importan las librerías que vamos a utilizar.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carga de set de datos

# %% [markdown]
# Se cargan los archivos del set de datos.

# %%
trata = pd.read_excel('set-de-datos/data_glotip.xlsx') #Lectura de Archivo

# %% [markdown]
# Informacion del dataframe.

# %%
trata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46558 entries, 0 to 46557
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UNODC              46532 non-null  object
#  1   unodc_ddds@un.org  45600 non-null  object
#  2   Unnamed: 2         45600 non-null  object
#  3   Unnamed: 3         45600 non-null  object
#  4   Unnamed: 4         46557 non-null  object
#  5   Unnamed: 5         46557 non-null  object
#  6   Unnamed: 6         46470 non-null  object
#  7   Unnamed: 7         46557 non-null  object
#  8   Unnamed: 8         46557 non-null  object
#  9   Unnamed: 9         46557 non-null  object
#  10  Unnamed: 10        46557 non-null  object
#  11  Unnamed: 11        46557 non-null  object
#  12  Unnamed: 12        46557 non-null  object
# dtypes: object(13)
# memory usage: 4.6+ MB

# %% [markdown]
# Se realiza vista previa del dataframe.

# %%
trata.head()
# Out:
#         UNODC unodc_ddds@un.org Unnamed: 2                       Unnamed: 3  \
# 0  30/05/2023               NaN        NaN                              NaN
# 1   Iso3_code           Country     Region                        Subregion
# 2         ABW             Aruba   Americas  Latin America and the Caribbean
# 3         AFG       Afghanistan       Asia                    Southern Asia
# 4         AFG       Afghanistan       Asia                    Southern Asia
#
#                      Unnamed: 4                  Unnamed: 5 Unnamed: 6  \
# 0                           NaN                         NaN        NaN
# 1                     Indicator                   Dimension   Category
# 2  Detected trafficking victims  by country of repatriation    Ukraine
# 3  Detected trafficking victims  by country of repatriation     Abroad
# 4  Detected trafficking victims  by country of repatriation     Abroad
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9          Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN                  NaN         NaN
# 1        Sex        Age       Year  Unit of measurement    txtVALUE
# 2      Total      Total       2010               Counts          <5
# 3      Total      Total       2003               Counts          <5
# 4      Total      Total       2008               Counts          <5
#
#   Unnamed: 12
# 0         NaN
# 1      Source
# 2      GLOTIP
# 3      GLOTIP
# 4      GLOTIP

# %% [markdown]
# Elimino el primer y segundo registro que son irrelevantes.

# %%
trata = trata.drop(0)
trata = trata.drop(1)

trata.head()
# Out:
#   UNODC unodc_ddds@un.org Unnamed: 2                       Unnamed: 3  \
# 2   ABW             Aruba   Americas  Latin America and the Caribbean
# 3   AFG       Afghanistan       Asia                    Southern Asia
# 4   AFG       Afghanistan       Asia                    Southern Asia
# 5   AFG       Afghanistan       Asia                    Southern Asia
# 6   AFG       Afghanistan       Asia                    Southern Asia
#
#                             Unnamed: 4                  Unnamed: 5 Unnamed: 6  \
# 2         Detected trafficking victims  by country of repatriation    Ukraine
# 3         Detected trafficking victims  by country of repatriation     Abroad
# 4         Detected trafficking victims  by country of repatriation     Abroad
# 5   Offences of trafficking in persons                       Total      Total
# 6  Persons brought into formal contact                       Total      Total
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 2      Total      Total       2010      Counts          <5      GLOTIP
# 3      Total      Total       2003      Counts          <5      GLOTIP
# 4      Total      Total       2008      Counts          <5      GLOTIP
# 5      Total      Total       2013      Counts         103      GLOTIP
# 6      Total      Total       2013      Counts         167      GLOTIP

# %% [markdown]
# Renombre de columnas.

# %%
trata.rename(columns={'UNODC': 'Code', 'unodc_ddds@un.org': 'Country', 'Unnamed: 2': 'Region', 'Unnamed: 3': 'Subregion', 'Unnamed: 4': 'Indicator', 'Unnamed: 5': 'Dimension', 'Unnamed: 6': 'Category', 'Unnamed: 7': 'Sex', 'Unnamed: 8': 'Age', 'Unnamed: 9': 'Year', 'Unnamed: 10': 'Unit', 'Unnamed: 11': 'Value',  'Unnamed: 12': 'Source'}, inplace=True)
trata.head()
# Out:
#   Code      Country    Region                        Subregion  \
# 2  ABW        Aruba  Americas  Latin America and the Caribbean
# 3  AFG  Afghanistan      Asia                    Southern Asia
# 4  AFG  Afghanistan      Asia                    Southern Asia
# 5  AFG  Afghanistan      Asia                    Southern Asia
# 6  AFG  Afghanistan      Asia                    Southern Asia
#
#                              Indicator                   Dimension Category  \
# 2         Detected trafficking victims  by country of repatriation  Ukraine
# 3         Detected trafficking victims  by country of repatriation   Abroad
# 4         Detected trafficking victims  by country of repatriation   Abroad
# 5   Offences of trafficking in persons                       Total    Total
# 6  Persons brought into formal contact                       Total    Total
#
#      Sex    Age  Year    Unit Value  Source
# 2  Total  Total  2010  Counts    <5  GLOTIP
# 3  Total  Total  2003  Counts    <5  GLOTIP
# 4  Total  Total  2008  Counts    <5  GLOTIP
# 5  Total  Total  2013  Counts   103  GLOTIP
# 6  Total  Total  2013  Counts   167  GLOTIP

# %%
trata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46556 entries, 2 to 46557
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Code       46530 non-null  object
#  1   Country    45599 non-null  object
#  2   Region     45599 non-null  object
#  3   Subregion  45599 non-null  object
#  4   Indicator  46556 non-null  object
#  5   Dimension  46556 non-null  object
#  6   Category   46469 non-null  object
#  7   Sex        46556 non-null  object
#  8   Age        46556 non-null  object
#  9   Year       46556 non-null  object
#  10  Unit       46556 non-null  object
#  11  Value      46556 non-null  object
#  12  Source     46556 non-null  object
# dtypes: object(13)
# memory usage: 4.6+ MB

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# Se revisa valores de Indicador.

# %%
valores_unicos = trata['Indicator'].unique()
list(valores_unicos)
# Out:
# ['Detected trafficking victims',
#  'Offences of trafficking in persons',
#  'Persons brought into formal contact',
#  'Persons prosecuted',
#  'Persons convicted']

# %% [markdown]
# Se revisa valores de Valor.

# %%
valores_unicos = trata['Value'].unique()
list(valores_unicos)
# Out:
# ['<5',
#  '103',
#  '167',
#  '15',
#  '7',
#  '34',
#  '5',
#  '12',
#  '17',
#  '10',
#  '27',
#  '23',
#  '9',
#  '24',
#  '6',
#  '21',
#  '28',
#  '8',
#  '20',
#  '40',
#  '44',
#  '62',
#  '49',
#  '57',
#  '56',
#  '25',
#  '16',
#  '92',
#  '108',
#  '14',
#  '22',
#  '72',
#  '94',
#  '83',
#  '97',
#  '37',
#  '51',
#  '39',
#  '45',
#  '84',
#  '26',
#  '66',
#  '30',
#  '43',
#  '52',
#  '95',
#  '53',
#  '42',
#  '63',
#  '125',
#  '31',
#  '48',
#  '61',
#  '109',
#  '74',
#  '36',
#  '67',
#  '60',
#  '58',
#  '91',
#  '33',
#  '54',
#  '46',
#  '65',
#  '41',
#  '35',
#  '86',
#  '112',
#  '47',
#  '159',
#  '38',
#  '59',
#  '32',
#  '11',
#  '139',
#  '13',
#  '152',
#  '29',
#  '258',
#  '169',
#  '111',
#  '75',
#  '87',
#  '70',
#  '192',
#  '64',
#  '149',
#  '19',
#  '50',
#  '131',
#  '106',
#  '77',
#  '73',
#  '18',
#  '129',
#  '186',
#  '114',
#  '338',
#  '422',
#  '168',
#  '254',
#  '178',
#  '224',
#  '263',
#  '196',
#  '118',
#  '150',
#  '76',
#  '236',
#  '289',
#  '303',
#  '79',
#  '88',
#  '215',
#  '1,757',
#  '540',
#  '117',
#  '204',
#  '340',
#  '374',
#  '127',
#  '213',
#  '161',
#  '2,004',
#  '628',
#  '238',
#  '133',
#  '319',
#  '375',
#  '81',
#  '142',
#  '209',
#  '163',
#  '182',
#  '2,386',
#  '512',
#  '138',
#  '115',
#  '222',
#  '243',
#  '116',
#  '184',
#  '194',
#  '2,948',
#  '100',
#  '147',
#  '279',
#  '370',
#  '414',
#  '90',
#  '203',
#  '197',
#  '220',
#  '1,981',
#  '69',
#  '619',
#  '503',
#  '1,122',
#  '1,200',
#  '569',
#  '404',
#  '776',
#  '423',
#  '68',
#  '825',
#  '655',
#  '1,482',
#  '1,531',
#  '738',
#  '531',
#  '132',
#  '972',
#  '552',
#  '671',
#  '807',
#  '101',
#  '1,489',
#  '1,590',
#  '1,094',
#  '134',
#  '255',
#  '624',
#  '55',
#  '879',
#  '934',
#  '493',
#  '501',
#  '544',
#  '362',
#  '494',
#  '865',
#  '933',
#  '688',
#  '82',
#  '489',
#  '605',
#  '644',
#  '202',
#  '235',
#  '490',
#  '794',
#  '113',
#  '1,290',
#  '1,404',
#  '1,110',
#  '158',
#  '136',
#  '752',
#  '888',
#  '948',
#  '290',
#  '328',
#  '71',
#  '166',
#  '179',
#  '123',
#  '189',
#  '80',
#  '174',
#  '193',
#  '233',
#  '120',
#  '244',
#  '162',
#  '234',
#  '99',
#  '105',
#  '126',
#  '98',
#  '200',
#  '324',
#  '354',
#  '128',
#  '232',
#  '242',
#  '327',
#  '343',
#  '96',
#  '144',
#  '267',
#  '278',
#  '176',
#  '124',
#  '212',
#  '130',
#  '135',
#  '93',
#  '78',
#  '146',
#  '453',
#  '122',
#  '367',
#  '371',
#  '874',
#  '592',
#  '593',
#  '604',
#  '602',
#  '635',
#  '558',
#  '102',
#  '89',
#  '389',
#  '612',
#  '473',
#  '461',
#  '543',
#  '121',
#  '355',
#  '185',
#  '313',
#  '446',
#  '154',
#  '331',
#  '140',
#  '316',
#  '488',
#  '361',
#  '535',
#  '536',
#  '322',
#  '627',
#  '521',
#  '402',
#  '368',
#  '603',
#  '788',
#  '426',
#  '588',
#  '532',
#  '483',
#  '799',
#  '1,282',
#  '1,112',
#  '199',
#  '351',
#  '550',
#  '308',
#  '564',
#  '872',
#  '1,740',
#  '175',
#  '428',
#  '104',
#  '206',
#  '310',
#  '366',
#  '683',
#  '272',
#  '247',
#  '373',
#  '620',
#  '733',
#  '1,423',
#  '210',
#  '502',
#  '561',
#  '685',
#  '730',
#  '85',
#  '223',
#  '288',
#  '110',
#  '250',
#  '251',
#  '297',
#  '292',
#  '326',
#  '429',
#  '357',
#  '387',
#  '470',
#  '394',
#  '451',
#  '513',
#  '579',
#  '198',
#  '427',
#  '538',
#  '491',
#  '433',
#  '450',
#  '409',
#  '346',
#  '406',
#  '353',
#  '376',
#  '287',
#  '314',
#  '294',
#  '388',
#  '298',
#  '329',
#  '312',
#  '323',
#  '407',
#  '466',
#  '508',
#  '284',
#  '309',
#  '336',
#  '396',
#  '443',
#  '280',
#  '369',
#  '457',
#  '444',
#  '107',
#  '282',
#  '119',
#  '143',
#  '350',
#  '157',
#  '400',
#  '260',
#  '365',
#  '173',
#  '214',
#  '1,011',
#  '356',
#  '395',
#  '418',
#  '378',
#  '293',
#  '164',
#  '591',
#  '458',
#  '363',
#  '398',
#  '333',
#  '345',
#  '217',
#  '273',
#  '295',
#  '208',
#  '231',
#  '270',
#  '274',
#  '205',
#  '399',
#  '421',
#  '285',
#  '187',
#  '239',
#  '463',
#  '181',
#  '183',
#  '778',
#  '968',
#  '195',
#  '301',
#  '895',
#  '148',
#  '141',
#  '160',
#  '397',
#  '332',
#  '299',
#  '339',
#  '151',
#  '305',
#  '211',
#  '145',
#  '390',
#  '590',
#  '379',
#  '1,159',
#  '1,228',
#  '304',
#  '750',
#  '1,054',
#  '586',
#  '248',
#  '165',
#  '171',
#  '237',
#  '155',
#  '188',
#  '268',
#  '229',
#  '265',
#  '300',
#  '382',
#  '546',
#  '275',
#  '286',
#  '553',
#  '264',
#  '276',
#  '245',
#  '315',
#  '380',
#  '306',
#  '471',
#  '341',
#  '191',
#  '405',
#  '2,161',
#  '1,353',
#  '2,413',
#  '1,636',
#  '6,166',
#  '6,115',
#  '2,396',
#  '455',
#  '1,127',
#  '1,884',
#  '1,194',
#  '411',
#  '2,400',
#  '172',
#  '137',
#  '642',
#  '775',
#  '568',
#  '585',
#  '689',
#  '496',
#  '511',
#  '692',
#  '676',
#  '528',
#  '710',
#  '651',
#  '767',
#  '547',
#  '672',
#  '640',
#  '626',
#  '787',
#  '475',
#  '530',
#  '542',
#  '478',
#  '648',
#  '485',
#  '526',
#  '583',
#  '216',
#  '481',
#  '557',
#  '403',
#  '523',
#  '416',
#  '383',
#  '597',
#  '391',
#  '440',
#  '551',
#  '434',
#  '347',
#  '349',
#  '415',
#  '386',
#  '487',
#  '360',
#  '401',
#  '472',
#  '384',
#  '307',
#  '325',
#  '413',
#  '221',
#  '2,020',
#  '180',
#  '190',
#  '1,382',
#  '1,263',
#  '1,723',
#  '156',
#  '296',
#  '601',
#  '419',
#  '439',
#  '252',
#  '377',
#  '670',
#  '153',
#  '201',
#  '758',
#  '259',
#  '257',
#  '499',
#  '177',
#  '277',
#  '269',
#  '609',
#  '207',
#  '723',
#  '344',
#  '594',
#  '680',
#  '330',
#  '664',
#  '486',
#  '507',
#  '522',
#  '1,389',
#  '697',
#  '969',
#  '669',
#  '482',
#  '281',
#  '1,151',
#  '1,432',
#  '657',
#  '1,593',
#  '837',
#  '638',
#  '999',
#  '909',
#  '1,182',
#  '1,516',
#  '565',
#  '981',
#  '1,196',
#  '1,089',
#  '1,100',
#  '789',
#  '533',
#  '935',
#  '1,415',
#  '808',
#  '1,124',
#  '1,525',
#  '641',
#  '949',
#  '1,492',
#  '742',
#  '1,486',
#  '722',
#  '1,052',
#  '923',
#  '1,387',
#  '1,087',
#  '1,552',
#  '556',
#  '1,020',
#  '928',
#  '318',
#  '549',
#  '555',
#  '225',
#  '261',
#  '816',
#  '435',
#  '359',
#  '321',
#  '170',
#  '227',
#  '596',
#  '410',
#  '219',
#  '226',
#  '334',
#  '812',
#  '1,639',
#  '1,304',
#  '1,380',
#  '2,116',
#  '3,022',
#  '5,138',
#  '2,868',
#  '1,746',
#  '880',
#  '1,844',
#  '2,248',
#  '2,009',
#  '3,128',
#  '3,857',
#  '6,985',
#  '1,421',
#  '2,631',
#  '1,926',
#  '1,075',
#  '2,252',
#  '3,470',
#  '3,608',
#  '4,545',
#  '5,860',
#  '10,627',
#  '1,705',
#  '798',
#  '467',
#  '372',
#  '2,864',
#  '887',
#  '993',
#  '2,337',
#  '3,797',
#  '1,400',
#  '2,207',
#  '1,240',
#  '1,079',
#  '1,538',
#  '3,843',
#  '3,540',
#  '4,946',
#  '5,087',
#  '10,613',
#  '1,663',
#  '462',
#  '3,724',
#  '381',
#  '1,615',
#  '2,827',
#  '652',
#  '1,266',
#  '517',
#  '611',
#  '240',
#  '246',
#  '271',
#  '484',
#  '256',
#  '425',
#  '266',
#  '424',
#  '317',
#  '476',
#  '647',
#  '228',
#  '218',
#  '479',
#  '574',
#  '1,156',
#  '519',
#  '607',
#  '358',
#  '291',
#  '431',
#  '441',
#  '1,192',
#  '1,361',
#  '1,372',
#  '1,469',
#  '6,202',
#  '17,870',
#  '6,341',
#  '20,390',
#  '7,075',
#  '23,053',
#  '5,201',
#  '25,844',
#  '1,742',
#  '9,934',
#  '1,565',
#  '8,512',
#  '3,422',
#  '3,517',
#  '7,802',
#  '2,137',
#  '7,559',
#  '3,554',
#  '8,098',
#  '1,570',
#  '3,940',
#  '7,602',
#  '1,497',
#  '2,024',
#  '2,037',
#  '3,553',
#  '2,345',
#  '5,898',
#  '1,770',
#  '1,275',
#  '2,854',
#  '5,528',
#  '249',
#  '4,209',
#  '1,247',
#  '2,472',
#  '1,587',
#  '2,834',
#  '2,954',
#  '5,788',
#  '1,189',
#  '1,922',
#  '2,465',
#  '5,362',
#  '432',
#  '3,922',
#  '1,172',
#  '2,907',
#  '795',
#  '2,914',
#  '3,702',
#  '6,616',
#  '1,505',
#  '2,080',
#  '2,260',
#  '5,128',
#  '3,638',
#  '845',
#  '1,952',
#  '1,377',
#  '2,222',
#  '2,487',
#  '4,709',
#  '2,298',
#  '1,466',
#  '1,714',
#  '4,966',
#  '3,661',
#  '459',
#  '464',
#  '656',
#  '715',
#  '509',
#  '436',
#  '735',
#  '1,193',
#  '2,467',
#  '262',
#  '1,164',
#  '1,856',
#  '663',
#  '392',
#  '610',
#  '998',
#  '1,545',
#  '385',
#  '1,066',
#  '393',
#  '1,449',
#  '1,842',
#  '1,964',
#  '756',
#  '442',
#  '1,147',
#  '1,514',
#  '2,128',
#  '348',
#  '545',
#  '966',
#  '302',
#  '1,414',
#  '1,653',
#  '2,141',
#  '417',
#  '813',
#  '1,543',
#  '1,951',
#  '2,313',
#  '2,644',
#  '492',
#  '757',
#  '430',
#  '283',
#  '352',
#  '634',
#  '684',
#  '320',
#  '562',
#  '744',
#  '342',
#  '571',
#  '859',
#  '524',
#  '740',
#  '1,023',
#  '2,015',
#  '554',
#  '253',
#  '714',
#  '777',
#  '986',
#  '839',
#  '527',
#  '633',
#  '970',
#  '731',
#  '311',
#  '824',
#  '643',
#  '408',
#  '666',
#  '452',
#  '646',
#  '515',
#  '498',
#  '712',
#  '495',
#  '516',
#  '840',
#  '1,044',
#  '1,119',
#  '695',
#  '1,269',
#  '600',
#  '1,250',
#  '852',
#  '412',
#  '976',
#  '849',
#  '364',
#  '587',
#  '716',
#  '708',
#  '1,030',
#  '815',
#  '468',
#  '896',
#  '1,017',
#  '721',
#  '1,001',
#  '783',
#  '1,107',
#  '1,890',
#  '1,012',
#  '447',
#  '581',
#  '1,173',
#  '1,099',
#  '958',
#  '823',
#  '506',
#  '573',
#  '1,152',
#  '1,078',
#  '1,068',
#  '460',
#  '687',
#  '768',
#  '702',
#  '1,470',
#  '699',
#  '701',
#  '779',
#  '615',
#  '826',
#  '725',
#  '831',
#  '749',
#  '1,013',
#  '1,222',
#  '337',
#  '781',
#  '1,303',
#  '1,478',
#  '1,711',
#  '1,216',
#  '1,035',
#  '1,178',
#  '1,434',
#  '945',
#  '914',
#  '1,256',
#  '761',
#  '1,150',
#  '497',
#  '675',
#  '480',
#  '952',
#  '760',
#  '606',
#  '668',
#  '1,105',
#  '1,334',
#  '1,134',
#  '916',
#  '984',
#  '241',
#  '834',
#  '682',
#  '2,023',
#  '1,526',
#  '1,642',
#  '11,478',
#  '3,920',
#  '477',
#  '713',
#  '705',
#  '696',
#  '449',
#  '907',
#  '734',
#  '504',
#  '832',
#  '335',
#  '537',
#  '802',
#  '529',
#  '763',
#  '694',
#  '639',
#  '747',
#  '1,114',
#  '445',
#  '1,220',
#  '1,659',
#  '920',
#  '1,707',
#  '2,318',
#  '621',
#  '1,578',
#  '2,041',
#  '1,073',
#  '469',
#  '741',
#  '1,293',
#  '1,598',
#  '931',
#  '230',
#  '706',
#  '1,780',
#  '877',
#  '724',
#  '780',
#  '847',
#  '1,154',
#  '717',
#  '729',
#  '1,048',
#  '1,041',
#  '810',
#  '1,296',
#  '1,848',
#  '1,771',
#  '1,647',
#  '454',
#  '662',
#  '661',
#  '946',
#  '884',
#  '518',
#  '698',
#  '686',
#  '728',
#  '897',
#  '595',
#  '570',
#  '505',
#  '903',
#  '2,077',
#  '2,679',
#  '2,718',
#  '2,423',
#  '2,702',
#  '979',
#  ...]

# %% [markdown]
# Reemplazar los valores "<5" por "5" en la columna "Valor"

# %%
trata['Value'] = trata['Value'].replace('<5', '3')

# %% [markdown]
# Reemplazar los valores "," por "" en la columna "Valor".

# %%
trata['Value'] = trata['Value'].str.replace(',', '')

# %% [markdown]
# Se revisa los valores unicos.

# %%
valores_unicos = trata['Value'].unique()
list(valores_unicos)
# Out:
# ['3',
#  '103',
#  '167',
#  '15',
#  '7',
#  '34',
#  '5',
#  '12',
#  '17',
#  '10',
#  '27',
#  '23',
#  '9',
#  '24',
#  '6',
#  '21',
#  '28',
#  '8',
#  '20',
#  '40',
#  '44',
#  '62',
#  '49',
#  '57',
#  '56',
#  '25',
#  '16',
#  '92',
#  '108',
#  '14',
#  '22',
#  '72',
#  '94',
#  '83',
#  '97',
#  '37',
#  '51',
#  '39',
#  '45',
#  '84',
#  '26',
#  '66',
#  '30',
#  '43',
#  '52',
#  '95',
#  '53',
#  '42',
#  '63',
#  '125',
#  '31',
#  '48',
#  '61',
#  '109',
#  '74',
#  '36',
#  '67',
#  '60',
#  '58',
#  '91',
#  '33',
#  '54',
#  '46',
#  '65',
#  '41',
#  '35',
#  '86',
#  '112',
#  '47',
#  '159',
#  '38',
#  '59',
#  '32',
#  '11',
#  '139',
#  '13',
#  '152',
#  '29',
#  '258',
#  '169',
#  '111',
#  '75',
#  '87',
#  '70',
#  '192',
#  '64',
#  '149',
#  '19',
#  '50',
#  '131',
#  '106',
#  '77',
#  '73',
#  '18',
#  '129',
#  '186',
#  '114',
#  '338',
#  '422',
#  '168',
#  '254',
#  '178',
#  '224',
#  '263',
#  '196',
#  '118',
#  '150',
#  '76',
#  '236',
#  '289',
#  '303',
#  '79',
#  '88',
#  '215',
#  '1757',
#  '540',
#  '117',
#  '204',
#  '340',
#  '374',
#  '127',
#  '213',
#  '161',
#  '2004',
#  '628',
#  '238',
#  '133',
#  '319',
#  '375',
#  '81',
#  '142',
#  '209',
#  '163',
#  '182',
#  '2386',
#  '512',
#  '138',
#  '115',
#  '222',
#  '243',
#  '116',
#  '184',
#  '194',
#  '2948',
#  '100',
#  '147',
#  '279',
#  '370',
#  '414',
#  '90',
#  '203',
#  '197',
#  '220',
#  '1981',
#  '69',
#  '619',
#  '503',
#  '1122',
#  '1200',
#  '569',
#  '404',
#  '776',
#  '423',
#  '68',
#  '825',
#  '655',
#  '1482',
#  '1531',
#  '738',
#  '531',
#  '132',
#  '972',
#  '552',
#  '671',
#  '807',
#  '101',
#  '1489',
#  '1590',
#  '1094',
#  '134',
#  '255',
#  '624',
#  '55',
#  '879',
#  '934',
#  '493',
#  '501',
#  '544',
#  '362',
#  '494',
#  '865',
#  '933',
#  '688',
#  '82',
#  '489',
#  '605',
#  '644',
#  '202',
#  '235',
#  '490',
#  '794',
#  '113',
#  '1290',
#  '1404',
#  '1110',
#  '158',
#  '136',
#  '752',
#  '888',
#  '948',
#  '290',
#  '328',
#  '71',
#  '166',
#  '179',
#  '123',
#  '189',
#  '80',
#  '174',
#  '193',
#  '233',
#  '120',
#  '244',
#  '162',
#  '234',
#  '99',
#  '105',
#  '126',
#  '98',
#  '200',
#  '324',
#  '354',
#  '128',
#  '232',
#  '242',
#  '327',
#  '343',
#  '96',
#  '144',
#  '267',
#  '278',
#  '176',
#  '124',
#  '212',
#  '130',
#  '135',
#  '93',
#  '78',
#  '146',
#  '453',
#  '122',
#  '367',
#  '371',
#  '874',
#  '592',
#  '593',
#  '604',
#  '602',
#  '635',
#  '558',
#  '102',
#  '89',
#  '389',
#  '612',
#  '473',
#  '461',
#  '543',
#  '121',
#  '355',
#  '185',
#  '313',
#  '446',
#  '154',
#  '331',
#  '140',
#  '316',
#  '488',
#  '361',
#  '535',
#  '536',
#  '322',
#  '627',
#  '521',
#  '402',
#  '368',
#  '603',
#  '788',
#  '426',
#  '588',
#  '532',
#  '483',
#  '799',
#  '1282',
#  '1112',
#  '199',
#  '351',
#  '550',
#  '308',
#  '564',
#  '872',
#  '1740',
#  '175',
#  '428',
#  '104',
#  '206',
#  '310',
#  '366',
#  '683',
#  '272',
#  '247',
#  '373',
#  '620',
#  '733',
#  '1423',
#  '210',
#  '502',
#  '561',
#  '685',
#  '730',
#  '85',
#  '223',
#  '288',
#  '110',
#  '250',
#  '251',
#  '297',
#  '292',
#  '326',
#  '429',
#  '357',
#  '387',
#  '470',
#  '394',
#  '451',
#  '513',
#  '579',
#  '198',
#  '427',
#  '538',
#  '491',
#  '433',
#  '450',
#  '409',
#  '346',
#  '406',
#  '353',
#  '376',
#  '287',
#  '314',
#  '294',
#  '388',
#  '298',
#  '329',
#  '312',
#  '323',
#  '407',
#  '466',
#  '508',
#  '284',
#  '309',
#  '336',
#  '396',
#  '443',
#  '280',
#  '369',
#  '457',
#  '444',
#  '107',
#  '282',
#  '119',
#  '143',
#  '350',
#  '157',
#  '400',
#  '260',
#  '365',
#  '173',
#  '214',
#  '1011',
#  '356',
#  '395',
#  '418',
#  '378',
#  '293',
#  '164',
#  '591',
#  '458',
#  '363',
#  '398',
#  '333',
#  '345',
#  '217',
#  '273',
#  '295',
#  '208',
#  '231',
#  '270',
#  '274',
#  '205',
#  '399',
#  '421',
#  '285',
#  '187',
#  '239',
#  '463',
#  '181',
#  '183',
#  '778',
#  '968',
#  '195',
#  '301',
#  '895',
#  '148',
#  '141',
#  '160',
#  '397',
#  '332',
#  '299',
#  '339',
#  '151',
#  '305',
#  '211',
#  '145',
#  '390',
#  '590',
#  '379',
#  '1159',
#  '1228',
#  '304',
#  '750',
#  '1054',
#  '586',
#  '248',
#  '165',
#  '171',
#  '237',
#  '155',
#  '188',
#  '268',
#  '229',
#  '265',
#  '300',
#  '382',
#  '546',
#  '275',
#  '286',
#  '553',
#  '264',
#  '276',
#  '245',
#  '315',
#  '380',
#  '306',
#  '471',
#  '341',
#  '191',
#  '405',
#  '2161',
#  '1353',
#  '2413',
#  '1636',
#  '6166',
#  '6115',
#  '2396',
#  '455',
#  '1127',
#  '1884',
#  '1194',
#  '411',
#  '2400',
#  '172',
#  '137',
#  '642',
#  '775',
#  '568',
#  '585',
#  '689',
#  '496',
#  '511',
#  '692',
#  '676',
#  '528',
#  '710',
#  '651',
#  '767',
#  '547',
#  '672',
#  '640',
#  '626',
#  '787',
#  '475',
#  '530',
#  '542',
#  '478',
#  '648',
#  '485',
#  '526',
#  '583',
#  '216',
#  '481',
#  '557',
#  '403',
#  '523',
#  '416',
#  '383',
#  '597',
#  '391',
#  '440',
#  '551',
#  '434',
#  '347',
#  '349',
#  '415',
#  '386',
#  '487',
#  '360',
#  '401',
#  '472',
#  '384',
#  '307',
#  '325',
#  '413',
#  '221',
#  '2020',
#  '180',
#  '190',
#  '1382',
#  '1263',
#  '1723',
#  '156',
#  '296',
#  '601',
#  '419',
#  '439',
#  '252',
#  '377',
#  '670',
#  '153',
#  '201',
#  '758',
#  '259',
#  '257',
#  '499',
#  '177',
#  '277',
#  '269',
#  '609',
#  '207',
#  '723',
#  '344',
#  '594',
#  '680',
#  '330',
#  '664',
#  '486',
#  '507',
#  '522',
#  '1389',
#  '697',
#  '969',
#  '669',
#  '482',
#  '281',
#  '1151',
#  '1432',
#  '657',
#  '1593',
#  '837',
#  '638',
#  '999',
#  '909',
#  '1182',
#  '1516',
#  '565',
#  '981',
#  '1196',
#  '1089',
#  '1100',
#  '789',
#  '533',
#  '935',
#  '1415',
#  '808',
#  '1124',
#  '1525',
#  '641',
#  '949',
#  '1492',
#  '742',
#  '1486',
#  '722',
#  '1052',
#  '923',
#  '1387',
#  '1087',
#  '1552',
#  '556',
#  '1020',
#  '928',
#  '318',
#  '549',
#  '555',
#  '225',
#  '261',
#  '816',
#  '435',
#  '359',
#  '321',
#  '170',
#  '227',
#  '596',
#  '410',
#  '219',
#  '226',
#  '334',
#  '812',
#  '1639',
#  '1304',
#  '1380',
#  '2116',
#  '3022',
#  '5138',
#  '2868',
#  '1746',
#  '880',
#  '1844',
#  '2248',
#  '2009',
#  '3128',
#  '3857',
#  '6985',
#  '1421',
#  '2631',
#  '1926',
#  '1075',
#  '2252',
#  '3470',
#  '3608',
#  '4545',
#  '5860',
#  '10627',
#  '1705',
#  '798',
#  '467',
#  '372',
#  '2864',
#  '887',
#  '993',
#  '2337',
#  '3797',
#  '1400',
#  '2207',
#  '1240',
#  '1079',
#  '1538',
#  '3843',
#  '3540',
#  '4946',
#  '5087',
#  '10613',
#  '1663',
#  '462',
#  '3724',
#  '381',
#  '1615',
#  '2827',
#  '652',
#  '1266',
#  '517',
#  '611',
#  '240',
#  '246',
#  '271',
#  '484',
#  '256',
#  '425',
#  '266',
#  '424',
#  '317',
#  '476',
#  '647',
#  '228',
#  '218',
#  '479',
#  '574',
#  '1156',
#  '519',
#  '607',
#  '358',
#  '291',
#  '431',
#  '441',
#  '1192',
#  '1361',
#  '1372',
#  '1469',
#  '6202',
#  '17870',
#  '6341',
#  '20390',
#  '7075',
#  '23053',
#  '5201',
#  '25844',
#  '1742',
#  '9934',
#  '1565',
#  '8512',
#  '3422',
#  '3517',
#  '7802',
#  '2137',
#  '7559',
#  '3554',
#  '8098',
#  '1570',
#  '3940',
#  '7602',
#  '1497',
#  '2024',
#  '2037',
#  '3553',
#  '2345',
#  '5898',
#  '1770',
#  '1275',
#  '2854',
#  '5528',
#  '249',
#  '4209',
#  '1247',
#  '2472',
#  '1587',
#  '2834',
#  '2954',
#  '5788',
#  '1189',
#  '1922',
#  '2465',
#  '5362',
#  '432',
#  '3922',
#  '1172',
#  '2907',
#  '795',
#  '2914',
#  '3702',
#  '6616',
#  '1505',
#  '2080',
#  '2260',
#  '5128',
#  '3638',
#  '845',
#  '1952',
#  '1377',
#  '2222',
#  '2487',
#  '4709',
#  '2298',
#  '1466',
#  '1714',
#  '4966',
#  '3661',
#  '459',
#  '464',
#  '656',
#  '715',
#  '509',
#  '436',
#  '735',
#  '1193',
#  '2467',
#  '262',
#  '1164',
#  '1856',
#  '663',
#  '392',
#  '610',
#  '998',
#  '1545',
#  '385',
#  '1066',
#  '393',
#  '1449',
#  '1842',
#  '1964',
#  '756',
#  '442',
#  '1147',
#  '1514',
#  '2128',
#  '348',
#  '545',
#  '966',
#  '302',
#  '1414',
#  '1653',
#  '2141',
#  '417',
#  '813',
#  '1543',
#  '1951',
#  '2313',
#  '2644',
#  '492',
#  '757',
#  '430',
#  '283',
#  '352',
#  '634',
#  '684',
#  '320',
#  '562',
#  '744',
#  '342',
#  '571',
#  '859',
#  '524',
#  '740',
#  '1023',
#  '2015',
#  '554',
#  '253',
#  '714',
#  '777',
#  '986',
#  '839',
#  '527',
#  '633',
#  '970',
#  '731',
#  '311',
#  '824',
#  '643',
#  '408',
#  '666',
#  '452',
#  '646',
#  '515',
#  '498',
#  '712',
#  '495',
#  '516',
#  '840',
#  '1044',
#  '1119',
#  '695',
#  '1269',
#  '600',
#  '1250',
#  '852',
#  '412',
#  '976',
#  '849',
#  '364',
#  '587',
#  '716',
#  '708',
#  '1030',
#  '815',
#  '468',
#  '896',
#  '1017',
#  '721',
#  '1001',
#  '783',
#  '1107',
#  '1890',
#  '1012',
#  '447',
#  '581',
#  '1173',
#  '1099',
#  '958',
#  '823',
#  '506',
#  '573',
#  '1152',
#  '1078',
#  '1068',
#  '460',
#  '687',
#  '768',
#  '702',
#  '1470',
#  '699',
#  '701',
#  '779',
#  '615',
#  '826',
#  '725',
#  '831',
#  '749',
#  '1013',
#  '1222',
#  '337',
#  '781',
#  '1303',
#  '1478',
#  '1711',
#  '1216',
#  '1035',
#  '1178',
#  '1434',
#  '945',
#  '914',
#  '1256',
#  '761',
#  '1150',
#  '497',
#  '675',
#  '480',
#  '952',
#  '760',
#  '606',
#  '668',
#  '1105',
#  '1334',
#  '1134',
#  '916',
#  '984',
#  '241',
#  '834',
#  '682',
#  '2023',
#  '1526',
#  '1642',
#  '11478',
#  '3920',
#  '477',
#  '713',
#  '705',
#  '696',
#  '449',
#  '907',
#  '734',
#  '504',
#  '832',
#  '335',
#  '537',
#  '802',
#  '529',
#  '763',
#  '694',
#  '639',
#  '747',
#  '1114',
#  '445',
#  '1220',
#  '1659',
#  '920',
#  '1707',
#  '2318',
#  '621',
#  '1578',
#  '2041',
#  '1073',
#  '469',
#  '741',
#  '1293',
#  '1598',
#  '931',
#  '230',
#  '706',
#  '1780',
#  '877',
#  '724',
#  '780',
#  '847',
#  '1154',
#  '717',
#  '729',
#  '1048',
#  '1041',
#  '810',
#  '1296',
#  '1848',
#  '1771',
#  '1647',
#  '454',
#  '662',
#  '661',
#  '946',
#  '884',
#  '518',
#  '698',
#  '686',
#  '728',
#  '897',
#  '595',
#  '570',
#  '505',
#  '903',
#  '2077',
#  '2679',
#  '2718',
#  '2423',
#  '2702',
#  '979',
#  ...]

# %% [markdown]
# Se cambia tipo de dato de Valor a float, para poder hacer cálculos.

# %%
trata['Value'] = trata['Value'].astype(int)

# %%
trata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46556 entries, 2 to 46557
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Code       46530 non-null  object
#  1   Country    45599 non-null  object
#  2   Region     45599 non-null  object
#  3   Subregion  45599 non-null  object
#  4   Indicator  46556 non-null  object
#  5   Dimension  46556 non-null  object
#  6   Category   46469 non-null  object
#  7   Sex        46556 non-null  object
#  8   Age        46556 non-null  object
#  9   Year       46556 non-null  object
#  10  Unit       46556 non-null  object
#  11  Value      46556 non-null  int32
#  12  Source     46556 non-null  object
# dtypes: int32(1), object(12)
# memory usage: 4.4+ MB

# %% [markdown]
# Corregir el Código pais y País de Aruba/Curacao.

# %%
trata[trata['Code'] == 'Aruba/Curacao']
# Out:
#                Code Country Region Subregion                     Indicator  \
# 2670  Aruba/Curacao     NaN    NaN       NaN  Detected trafficking victims
#
#                        Dimension                            Category    Sex  \
# 2670  by country of repatriation  Venezuela (Bolivarian Republic of)  Total
#
#         Age  Year    Unit  Value  Source
# 2670  Total  2011  Counts      3  GLOTIP

# %% [markdown]
# Agrega el Código.

# %%
for x in trata.index:
  if trata.loc[x, 'Code'] == 'Aruba/Curacao':
     trata.loc[x, 'Code'] = 'ABW'

# %%
trata[trata['Code'] == 'ABW']
# Out:
#      Code Country    Region                        Subregion  \
# 2     ABW   Aruba  Americas  Latin America and the Caribbean
# 2670  ABW     NaN       NaN                              NaN
#
#                          Indicator                   Dimension  \
# 2     Detected trafficking victims  by country of repatriation
# 2670  Detected trafficking victims  by country of repatriation
#
#                                 Category    Sex    Age  Year    Unit  Value  \
# 2                                Ukraine  Total  Total  2010  Counts      3
# 2670  Venezuela (Bolivarian Republic of)  Total  Total  2011  Counts      3
#
#       Source
# 2     GLOTIP
# 2670  GLOTIP

# %% [markdown]
# Agrega el pais.

# %%
trata.loc[2670, 'Country'] = 'Aruba/Curacao'
trata[trata['Code'] == 'ABW']
# Out:
#      Code        Country    Region                        Subregion  \
# 2     ABW          Aruba  Americas  Latin America and the Caribbean
# 2670  ABW  Aruba/Curacao       NaN                              NaN
#
#                          Indicator                   Dimension  \
# 2     Detected trafficking victims  by country of repatriation
# 2670  Detected trafficking victims  by country of repatriation
#
#                                 Category    Sex    Age  Year    Unit  Value  \
# 2                                Ukraine  Total  Total  2010  Counts      3
# 2670  Venezuela (Bolivarian Republic of)  Total  Total  2011  Counts      3
#
#       Source
# 2     GLOTIP
# 2670  GLOTIP

# %% [markdown]
# Agrega region y subregion.

# %%
trata.loc[2670, 'Region'] = 'Americas'
trata[trata['Code'] == 'ABW']
# Out:
#      Code        Country    Region                        Subregion  \
# 2     ABW          Aruba  Americas  Latin America and the Caribbean
# 2670  ABW  Aruba/Curacao  Americas                              NaN
#
#                          Indicator                   Dimension  \
# 2     Detected trafficking victims  by country of repatriation
# 2670  Detected trafficking victims  by country of repatriation
#
#                                 Category    Sex    Age  Year    Unit  Value  \
# 2                                Ukraine  Total  Total  2010  Counts      3
# 2670  Venezuela (Bolivarian Republic of)  Total  Total  2011  Counts      3
#
#       Source
# 2     GLOTIP
# 2670  GLOTIP

# %%
trata.loc[2670, 'Subregion'] = 'Latin America and the Caribbean'
trata[trata['Code'] == 'ABW']
# Out:
#      Code        Country    Region                        Subregion  \
# 2     ABW          Aruba  Americas  Latin America and the Caribbean
# 2670  ABW  Aruba/Curacao  Americas  Latin America and the Caribbean
#
#                          Indicator                   Dimension  \
# 2     Detected trafficking victims  by country of repatriation
# 2670  Detected trafficking victims  by country of repatriation
#
#                                 Category    Sex    Age  Year    Unit  Value  \
# 2                                Ukraine  Total  Total  2010  Counts      3
# 2670  Venezuela (Bolivarian Republic of)  Total  Total  2011  Counts      3
#
#       Source
# 2     GLOTIP
# 2670  GLOTIP

# %% [markdown]
# Agrego el código ISO al País Sark.

# %%
for x in trata.index:
  if trata.loc[x, 'Country'] == 'Sark':
     trata.loc[x, 'Code'] = 'CRQ'

# %%
trata[trata['Country'] == 'Sark']
# Out:
#       Code Country  Region        Subregion                     Indicator  \
# 37753  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37754  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37755  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37756  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37757  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37758  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37759  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37760  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37761  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37762  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37763  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37764  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37765  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37766  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37767  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37768  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37769  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37770  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 37771  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 42475  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 42476  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 42477  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 42478  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 42479  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 42480  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
# 42481  CRQ    Sark  Europe  Northern Europe  Detected trafficking victims
#
#                      Dimension                     Category     Sex  \
# 37753                    Total                        Total  Female
# 37754                    Total                        Total  Female
# 37755                    Total                        Total  Female
# 37756                    Total                        Total    Male
# 37757  by form of exploitation          Sexual exploitation    Male
# 37758                    Total                        Total  Female
# 37759                    Total                        Total    Male
# 37760  by form of exploitation          Sexual exploitation    Male
# 37761                    Total                        Total  Female
# 37762                    Total                        Total  Female
# 37763                    Total                        Total    Male
# 37764  by form of exploitation                Forced labour  Female
# 37765                    Total                        Total  Female
# 37766                    Total                        Total  Female
# 37767                    Total                        Total    Male
# 37768                    Total                        Total  Female
# 37769                    Total                        Total    Male
# 37770                    Total                        Total  Female
# 37771                    Total                        Total    Male
# 42475  by form of exploitation  Other forms of exploitation  Female
# 42476  by form of exploitation  Other forms of exploitation  Female
# 42477  by form of exploitation  Other forms of exploitation    Male
# 42478  by form of exploitation  Other forms of exploitation  Female
# 42479  by form of exploitation  Other forms of exploitation    Male
# 42480  by form of exploitation  Other forms of exploitation  Female
# 42481  by form of exploitation  Other forms of exploitation    Male
#
#                     Age  Year    Unit  Value  Source
# 37753     0 to 17 years  2017  Counts      3  GLOTIP
# 37754     0 to 17 years  2018  Counts      3  GLOTIP
# 37755  18 years or over  2018  Counts      3  GLOTIP
# 37756     0 to 17 years  2018  Counts      3  GLOTIP
# 37757  18 years or over  2018  Counts      3  GLOTIP
# 37758     0 to 17 years  2019  Counts      3  GLOTIP
# 37759     0 to 17 years  2019  Counts      3  GLOTIP
# 37760  18 years or over  2019  Counts      3  GLOTIP
# 37761     0 to 17 years  2020  Counts      3  GLOTIP
# 37762  18 years or over  2020  Counts      3  GLOTIP
# 37763     0 to 17 years  2020  Counts      3  GLOTIP
# 37764  18 years or over  2020  Counts      3  GLOTIP
# 37765             Total  2017  Counts      3  GLOTIP
# 37766             Total  2018  Counts      5  GLOTIP
# 37767             Total  2018  Counts      3  GLOTIP
# 37768             Total  2019  Counts      3  GLOTIP
# 37769             Total  2019  Counts      3  GLOTIP
# 37770             Total  2020  Counts      6  GLOTIP
# 37771             Total  2020  Counts      3  GLOTIP
# 42475     0 to 17 years  2017  Counts      3  GLOTIP
# 42476     0 to 17 years  2018  Counts      3  GLOTIP
# 42477     0 to 17 years  2018  Counts      3  GLOTIP
# 42478     0 to 17 years  2019  Counts      3  GLOTIP
# 42479     0 to 17 years  2019  Counts      3  GLOTIP
# 42480     0 to 17 years  2020  Counts      3  GLOTIP
# 42481     0 to 17 years  2020  Counts      3  GLOTIP

# %%
trata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46556 entries, 2 to 46557
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Code       46556 non-null  object
#  1   Country    45600 non-null  object
#  2   Region     45600 non-null  object
#  3   Subregion  45600 non-null  object
#  4   Indicator  46556 non-null  object
#  5   Dimension  46556 non-null  object
#  6   Category   46469 non-null  object
#  7   Sex        46556 non-null  object
#  8   Age        46556 non-null  object
#  9   Year       46556 non-null  object
#  10  Unit       46556 non-null  object
#  11  Value      46556 non-null  int32
#  12  Source     46556 non-null  object
# dtypes: int32(1), object(12)
# memory usage: 4.4+ MB

# %% [markdown]
# Se eliminan códigos de pais inexistentes sin datos de descripción de País, región y subregión.

# %%
conjunto_valores = ['CAR', 'CAS', 'MCA', 'MCN', 'EEU', 'SAF', 'SAM' ]
condicion = trata['Code'].isin(conjunto_valores)
trata = trata.drop(trata[condicion].index)

# %% [markdown]
# Verifica valores únicos para Código.

# %%
valores_unicos = trata['Code'].unique()
list(valores_unicos)
# Out:
# ['ABW',
#  'AFG',
#  'AGO',
#  'ALB',
#  'AND',
#  'ARE',
#  'ARG',
#  'ARM',
#  'ATG',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BFA',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BHS',
#  'BIH',
#  'BLR',
#  'BLZ',
#  'BOL',
#  'BRA',
#  'BRB',
#  'BRN',
#  'BTN',
#  'BWA',
#  'CAF',
#  'CAN',
#  'CHE',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COK',
#  'COL',
#  'COM',
#  'CPV',
#  'CRI',
#  'CUB',
#  'CUW',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DJI',
#  'DMA',
#  'DNK',
#  'DOM',
#  'DZA',
#  'ECU',
#  'EGY',
#  'ESP',
#  'EST',
#  'ETH',
#  'FIN',
#  'FJI',
#  'FRA',
#  'FSM',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GHA',
#  'GIN',
#  'GMB',
#  'GNB',
#  'GNQ',
#  'GRC',
#  'GRD',
#  'GTM',
#  'GUY',
#  'HKG',
#  'HND',
#  'HRV',
#  'HTI',
#  'HUN',
#  'IDN',
#  'IND',
#  'IRL',
#  'IRN',
#  'IRQ',
#  'ISL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JOR',
#  'JPN',
#  'KAZ',
#  'KEN',
#  'KGZ',
#  'KHM',
#  'KIR',
#  'KNA',
#  'KOR',
#  'KWT',
#  'LAO',
#  'LBN',
#  'LBR',
#  'LBY',
#  'LCA',
#  'LIE',
#  'LKA',
#  'LSO',
#  'LTU',
#  'LUX',
#  'LVA',
#  'MAC',
#  'MAR',
#  'MCO',
#  'MDA',
#  'MDG',
#  'MDV',
#  'MEX',
#  'MHL',
#  'MKD',
#  'MLI',
#  'MLT',
#  'MMR',
#  'MNE',
#  'MNG',
#  'MOZ',
#  'MRT',
#  'MUS',
#  'MWI',
#  'MYS',
#  'NAM',
#  'NER',
#  'NGA',
#  'NIC',
#  'NIU',
#  'NLD',
#  'NOR',
#  'NPL',
#  'NRU',
#  'NZL',
#  'OMN',
#  'PAK',
#  'PAN',
#  'PER',
#  'PHL',
#  'PLW',
#  'PNG',
#  'POL',
#  'PRI',
#  'PRK',
#  'PRT',
#  'PRY',
#  'PYF',
#  'QAT',
#  'ROU',
#  'RUS',
#  'RWA',
#  'SAU',
#  'SDN',
#  'SEN',
#  'SGP',
#  'SLB',
#  'SLE',
#  'SLV',
#  'SMR',
#  'SRB',
#  'SSD',
#  'SUR',
#  'SVK',
#  'SVN',
#  'SWE',
#  'SWZ',
#  'SYC',
#  'SYR',
#  'TCD',
#  'TGO',
#  'THA',
#  'TJK',
#  'TKM',
#  'TLS',
#  'TON',
#  'TTO',
#  'TUN',
#  'TUR',
#  'TUV',
#  'TZA',
#  'UGA',
#  'UKR',
#  'URY',
#  'USA',
#  'UZB',
#  'VAT',
#  'VCT',
#  'VEN',
#  'VNM',
#  'VUT',
#  'WSM',
#  'YEM',
#  'ZAF',
#  'ZMB',
#  'ZWE',
#  'CRQ']

# %%
trata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45600 entries, 2 to 46557
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Code       45600 non-null  object
#  1   Country    45600 non-null  object
#  2   Region     45600 non-null  object
#  3   Subregion  45600 non-null  object
#  4   Indicator  45600 non-null  object
#  5   Dimension  45600 non-null  object
#  6   Category   45513 non-null  object
#  7   Sex        45600 non-null  object
#  8   Age        45600 non-null  object
#  9   Year       45600 non-null  object
#  10  Unit       45600 non-null  object
#  11  Value      45600 non-null  int32
#  12  Source     45600 non-null  object
# dtypes: int32(1), object(12)
# memory usage: 4.7+ MB

# %% [markdown]
# Se verifican valores únicos de País.

# %%
valores_unicos = trata['Country'].unique()
list(valores_unicos)
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Aruba/Curacao',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bolivia (Plurinational State of)',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Switzerland',
#  'Chile',
#  'China',
#  'Côte d’Ivoire',
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Congo',
#  'Cook Islands',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czechia',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Egypt',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'France',
#  'Micronesia (Federated States of)',
#  'Gabon',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Georgia',
#  'Ghana',
#  'Guinea',
#  'Gambia',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guyana',
#  'China, Hong Kong Special Administrative Region',
#  'Honduras',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'Indonesia',
#  'India',
#  'Ireland',
#  'Iran (Islamic Republic of)',
#  'Iraq',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Jordan',
#  'Japan',
#  'Kazakhstan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Cambodia',
#  'Kiribati',
#  'Saint Kitts and Nevis',
#  'Republic of Korea',
#  'Kuwait',
#  "Lao People's Democratic Republic",
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Saint Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'China, Macao Special Administrative Region',
#  'Morocco',
#  'Monaco',
#  'Republic of Moldova',
#  'Madagascar',
#  'Maldives',
#  'Mexico',
#  'Marshall Islands',
#  'North Macedonia',
#  'Mali',
#  'Malta',
#  'Myanmar',
#  'Montenegro',
#  'Mongolia',
#  'Mozambique',
#  'Mauritania',
#  'Mauritius',
#  'Malawi',
#  'Malaysia',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Nicaragua',
#  'Niue',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'Nauru',
#  'New Zealand',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Palau',
#  'Papua New Guinea',
#  'Poland',
#  'Puerto Rico',
#  "Democratic People's Republic of Korea",
#  'Portugal',
#  'Paraguay',
#  'French Polynesia',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saudi Arabia',
#  'Sudan',
#  'Senegal',
#  'Singapore',
#  'Solomon Islands',
#  'Sierra Leone',
#  'El Salvador',
#  'San Marino',
#  'Serbia',
#  'South Sudan',
#  'Suriname',
#  'Slovakia',
#  'Slovenia',
#  'Sweden',
#  'Eswatini',
#  'Seychelles',
#  'Syrian Arab Republic',
#  'Chad',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Turkmenistan',
#  'Timor-Leste',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Türkiye',
#  'Tuvalu',
#  'United Republic of Tanzania',
#  'Uganda',
#  'Ukraine',
#  'Uruguay',
#  'United States of America',
#  'Uzbekistan',
#  'Holy See',
#  'Saint Vincent and the Grenadines',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam',
#  'Vanuatu',
#  'Samoa',
#  'Yemen',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe',
#  'Sark']

# %%
valores_unicos = trata['Region'].unique()
list(valores_unicos)
# Out:
# ['Americas', 'Asia', 'Africa', 'Europe', 'Oceania']

# %%
valores_unicos = trata['Subregion'].unique()
list(valores_unicos)
# Out:
# ['Latin America and the Caribbean',
#  'Southern Asia',
#  'Sub-Saharan Africa',
#  'Southern Europe',
#  'Western Asia',
#  'Australia and New Zealand',
#  'Western Europe',
#  'Eastern Europe',
#  'South-eastern Asia',
#  'Northern America',
#  'Eastern Asia',
#  'Polynesia',
#  'Northern Europe',
#  'Northern Africa',
#  'Melanesia',
#  'Micronesia',
#  'Central Asia']

# %%
trata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45600 entries, 2 to 46557
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Code       45600 non-null  object
#  1   Country    45600 non-null  object
#  2   Region     45600 non-null  object
#  3   Subregion  45600 non-null  object
#  4   Indicator  45600 non-null  object
#  5   Dimension  45600 non-null  object
#  6   Category   45513 non-null  object
#  7   Sex        45600 non-null  object
#  8   Age        45600 non-null  object
#  9   Year       45600 non-null  object
#  10  Unit       45600 non-null  object
#  11  Value      45600 non-null  int32
#  12  Source     45600 non-null  object
# dtypes: int32(1), object(12)
# memory usage: 4.7+ MB

# %%
valores_unicos = trata['Dimension'].unique()
list(valores_unicos)
# Out:
# ['by country of repatriation',
#  'Total',
#  'by form of exploitation',
#  'by citizenship']

# %% [markdown]
# Dejamos solo los valores para formas de explotacion

# %%
trata_exp=trata

# %%
trata_exp = trata_exp[trata_exp['Dimension'] == 'by form of exploitation']

# %%
trata_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12826 entries, 7 to 46557
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Code       12826 non-null  object
#  1   Country    12826 non-null  object
#  2   Region     12826 non-null  object
#  3   Subregion  12826 non-null  object
#  4   Indicator  12826 non-null  object
#  5   Dimension  12826 non-null  object
#  6   Category   12826 non-null  object
#  7   Sex        12826 non-null  object
#  8   Age        12826 non-null  object
#  9   Year       12826 non-null  object
#  10  Unit       12826 non-null  object
#  11  Value      12826 non-null  int32
#  12  Source     12826 non-null  object
# dtypes: int32(1), object(12)
# memory usage: 1.3+ MB

# %%
valores_unicos = trata_exp['Category'].unique()
list(valores_unicos)
# Out:
# ['Forced labour', 'Sexual exploitation', 'Other forms of exploitation']

# %%
valores_unicos = trata_exp['Sex'].unique()
list(valores_unicos)
# Out:
# ['Total', 'Female', 'Male', 'Other', 'Unknown']

# %%
trata_exp = trata_exp[trata_exp["Sex"] != 'Total']

# %%
trata_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5741 entries, 42 to 46556
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Code       5741 non-null   object
#  1   Country    5741 non-null   object
#  2   Region     5741 non-null   object
#  3   Subregion  5741 non-null   object
#  4   Indicator  5741 non-null   object
#  5   Dimension  5741 non-null   object
#  6   Category   5741 non-null   object
#  7   Sex        5741 non-null   object
#  8   Age        5741 non-null   object
#  9   Year       5741 non-null   object
#  10  Unit       5741 non-null   object
#  11  Value      5741 non-null   int32
#  12  Source     5741 non-null   object
# dtypes: int32(1), object(12)
# memory usage: 605.5+ KB

# %%
valores_unicos = trata_exp['Age'].unique()
list(valores_unicos)
# Out:
# ['0 to 17 years', '18 years or over', 'Unknown']

# %%
valores_unicos = trata_exp['Indicator'].unique()
list(valores_unicos)
# Out:
# ['Detected trafficking victims']

# %%
valores_unicos = trata_exp['Year'].unique()
list(valores_unicos)
# Out:
# [2017, 2018, 2019, 2020, 2021, 2014, 2015, 2016]

# %% [markdown]
# ## Análisis exploratorio de datos

# %%
trata_exp.head()
# Out:
#    Code Country  Region           Subregion                     Indicator  \
# 42  AGO  Angola  Africa  Sub-Saharan Africa  Detected trafficking victims
# 43  AGO  Angola  Africa  Sub-Saharan Africa  Detected trafficking victims
# 44  AGO  Angola  Africa  Sub-Saharan Africa  Detected trafficking victims
# 45  AGO  Angola  Africa  Sub-Saharan Africa  Detected trafficking victims
# 49  AGO  Angola  Africa  Sub-Saharan Africa  Detected trafficking victims
#
#                   Dimension             Category     Sex               Age  \
# 42  by form of exploitation        Forced labour  Female     0 to 17 years
# 43  by form of exploitation        Forced labour  Female  18 years or over
# 44  by form of exploitation        Forced labour    Male     0 to 17 years
# 45  by form of exploitation        Forced labour    Male  18 years or over
# 49  by form of exploitation  Sexual exploitation  Female     0 to 17 years
#
#     Year    Unit  Value  Source
# 42  2017  Counts      3  GLOTIP
# 43  2017  Counts      3  GLOTIP
# 44  2017  Counts     12  GLOTIP
# 45  2017  Counts      5  GLOTIP
# 49  2017  Counts      3  GLOTIP

# %%
# Agrupar los datos por el valor único en la columna "Code" y calcular la suma de los valores para cada código
data_grouped = trata_exp.groupby('Region')['Value'].sum()

# Crear un gráfico de torta
plt.figure(figsize=(8, 8))
plt.pie(data_grouped, labels=data_grouped.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Cantidad de Víctimas de trata detectadas por Region.')
plt.show()

# %%
# Agrupar los datos por año y calcular la suma de los valores para cada año
data_grouped = trata_exp.groupby('Subregion')['Value'].sum()

# Crear un gráfico de barras
plt.figure(figsize=(10,6))
data_grouped.plot(kind='bar', color='salmon')
plt.title('Cantidad de Víctimas de trata detectadas por Subregión.')
plt.xlabel('Subregion')
plt.ylabel('Valores')
plt.grid(axis='y')
plt.show()

# %%
# Agrupar los datos por año y calcular la suma de los valores para cada año
data_grouped = trata_exp.groupby('Year')['Value'].sum()

# Crear un gráfico de barras
plt.figure(figsize=(10,6))
data_grouped.plot(kind='bar', color='skyblue')
plt.title('Cantidad de Víctimas de trata detectadas por año.')
plt.xlabel('Año')
plt.ylabel('Valores')
plt.grid(axis='y')
plt.show()
