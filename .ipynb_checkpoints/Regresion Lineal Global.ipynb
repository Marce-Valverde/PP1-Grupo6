# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Carga set de datos limpio.

# %%
import os
print(os.path.abspath('set-de-datos/trata_exp.csv'))
# Out:
# c:\Users\gisel\Downloads\practica g6\PP1-Grupo6\.ipynb_checkpoints\set-de-datos\trata_exp.csv

# %%
trata_exp = pd.read_csv('C:/Users/gisel/Downloads/practica g6/PP1-Grupo6/trata_exp.csv') #Lectura de Archivo

# %% [markdown]
# # Regresión Lineal.

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Variables a usar: Año y la suma de los totales de casos por año.

# %%
numero_casos= trata_exp.groupby('Year')['Value'].sum().reset_index()

numero_casos
# Out:
#    Year  Value
# 0  2014   7954
# 1  2015  10961
# 2  2016  10959
# 3  2017  21794
# 4  2018  22252
# 5  2019  40266
# 6  2020  39023
# 7  2021  24267

# %%
plt.ylabel("Numero de casos")
plt.xlabel("Año")
plt.scatter(numero_casos["Year"], numero_casos["Value"], color="pink")
plt.show()

# %% [markdown]
# Aplico el modelo.

# %%
regresion1 = linear_model.LinearRegression()

# %%
años1= numero_casos["Year"].values.reshape((-1,1))
años1
# Out:
# array([[2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018],
#        [2019],
#        [2020],
#        [2021]], dtype=int64)

# %%
X= años1
y = numero_casos["Value"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# Visualizar los datos de entrenamiento y de prueba.

# %%
plt.scatter(X_train, y_train, label="Datos de entrenamiento", color="r", alpha=.7)
plt.scatter(X_test, y_test, label="Datros de prueba", color="g", alpha=.7)
plt.legend()
plt.title("Relación de datos")
plt.show()

# %% [markdown]
# Visualizar los datos a trabajar.

# %%
plt.figure(figsize= (5,3))
plt.scatter(X_train, y_train)
plt.ticklabel_format(style="plain")

plt.xlabel("Año")
plt.ylabel("Casos")
plt.title("Total de casos por año")
plt.show()

# %%
regr1 = LinearRegression()

# %%
regr1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(f"Coeficiente :{regr1.coef_[0]}")
# Out:
# Coeficiente :3477.732558139534

# %%
print(f"Intercepto: {regr1.intercept_}")
# Out:
# Intercepto: -6995796.395348836

# %%
y_predict1 = regr1.predict (X_test)
y_predict1
# Out:
# array([11834.70930232, 25745.63953488,  8356.97674419])

# %%
from sklearn.metrics import r2_score

escor= r2_score(y_test, y_predict1)
escor
# Out:
# 0.6677111445647981

# %%
plt.figure(figsize=(5,3))
plt.plot(X, y, "o")
plt.plot(X_test,y_predict1)
plt.title ("y_predict vs. X")
plt.xlabel("X")
plt.ylabel("y_predict1")
plt.ticklabel_format(style="plain")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Predicción hasta el año 2040.

# %%
X_future1 = np.array(range(2021,2041)).reshape(-1,1)
X_future1.shape
# Out:
# (20, 1)

# %%
futuro1 =regr1.predict(X_future1)

# %%
plt.figure(figsize=(5,3))
plt.plot(X, y, "o")
plt.plot(X_test, y_predict1)
plt.scatter(X_future1, futuro1, color= "red")
plt.title ("Pronostico de casos")
plt.xlabel("Años")
plt.ylabel("Casos en promedio")
plt.ticklabel_format(style="plain")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
